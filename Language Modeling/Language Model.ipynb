# %% [markdown]
# # Language Model

# %% [markdown]
# - A Language Model (LM) is a system that predicts the probability of a sequence of words.
# - A language model is a probabilistic model that predicts the likelihood of a sequence of words and is used to generate or understand natural language.
#
# In Simple terms:
# - A Language model answers the question: "How Likely is this sentence in a language?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# # Statistical Language Models
# - These are classical NLP approaches.
# - They rely on word frequency and probabilities.
#
# Main technique:
# 1. N-Gram Language Model
# 2. Unigram Model
# 3. Bigram Model
# 4. Trigram Model

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Problems with N-GRAM Model
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---

# %% [markdown]
# ## Neural Language Models
#
# - Neural networds improved language modeling.
# - Instead of storing huge probability table, they learn dence representation (Embeddings).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
